# %%
from toronto_open_data import TorontoOpenData

# %%
toronto_open_data = TorontoOpenData()

# %%
toronto_open_data.load(name='toronto-signature-sites', filename='Toronto Signature Sites - 4326.gpkg')
# Out:
#     _id  objectid   id                         site_name          district  \
# 0     1         1    2               100 Consilium Place       Scarborough
# 1     2         2    3         1035 Sheppard Avenue West        North York
# 2     3         3    4      125 and 155 Queens Quay East           Toronto
# 3     4         6    7  2075 Kennedy Road at Highway 401       Scarborough
# 4     5         7    8              2075 McNicoll Avenue       Scarborough
# ..  ...       ...  ...                               ...               ...
# 74   75       110  201                 675 Petrolia Road        North York
# 75   76       112  203                 176 Cherry Street           Toronto
# 76   77       113  204              1120 Birchmount Road       Scarborough
# 77   78       114  205                    200 Bay Street  Downtown Toronto
# 78   79       115    0               376 Birchmount Road       Scarborough
#
#                                             statement  \
# ...

# %%
toronto_open_data.load('ttc-streetcar-delay-data','ttc-streetcar-delay-data-2014')
# Out:
#     Report Date  Route      Time        Day                        Location  \
# 0    2014-01-02    505  06:31:00   Thursday         Dundas and Roncesvalles
# 1    2014-01-02    504  12:43:00   Thursday                   King and Shaw
# 2    2014-01-02    501  14:01:00   Thursday       Kingston road and Bingham
# 3    2014-01-02    504  14:22:00   Thursday  King St. and Roncesvalles Ave.
# 4    2014-01-02    504  16:42:00   Thursday               King and Bathurst
# ..          ...    ...       ...        ...                             ...
# 314  2014-01-19    501  21:32:00     Sunday                   Wolseley Loop
# 315  2014-01-19    510  21:46:00     Sunday          Bremner and Navy Wharf
# 316  2014-01-21    510  02:27:00    Tuesday             Spadina and Harbord
# 317  2014-01-29    510  18:42:00  Wednesday          Spadina Stn to King St
# 318  2014-01-31    504  13:00:00     Friday                      King Route
#
# ...

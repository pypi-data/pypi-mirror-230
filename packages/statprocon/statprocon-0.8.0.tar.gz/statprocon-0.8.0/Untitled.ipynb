# %%
import pandas as pd
from statprocon import XmR

counts = [
            '55.6', '54.7', '54.9', '54.8', '56.9', '55.7', '53.8', '54.8', '53.4', '57.0', '59.4', '63.2',
            '60.9', '60.7', '58.6', '57.3', '56.9', '58.1', '58.3', '50.9', '53.3', '52.5', '50.8', '52.9',
        ]
xmr = XmR(counts)
xmr
# Out:
# x_values : [55.6, 54.7, 54.9, 54.8, 56.9, 55.7, 53.8, 54.8, 53.4, 57.0, 59.4, 63.2, 60.9, 60.7, 58.6, 57.3, 56.9, 58.1, 58.3, 50.9, 53.3, 52.5, 50.8, 52.9]
# x_unpl   : [60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766, 60.766]
# x_cl     : [56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058, 56.058]
# x_lnpl   : [51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350, 51.350]
# mr_values: [None, 0.9, 0.2, 0.1, 2.1, 1.2, 1.9, 1.0, 1.4, 3.6, 2.4, 3.8, 2.3, 0.2, 2.1, 1.3, 0.4, 1.2, 0.2, 7.4, 2.4, 0.8, 1.7, 2.1]
# mr_url   : [5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784, 5.784]
# mr_cl    : [1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770, 1.770]

# %%
index = ['J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D', 'J', 'F', 'M', 'A', 'M', 'J', 'J', 'A', 'S', 'O', 'N', 'D']
xmr.x_plot(pd, index)
xmr.mr_plot(pd, index)
# Out:
# <Axes: >

# %%
xmr.mr_plot(pd)
# Out:
# <Axes: >
